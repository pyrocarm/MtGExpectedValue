# %% [markdown]
# # Scraping Card Prices to find the Expected Value, Variance, and Distribution of Sealed M:tG Product

# %% [markdown]
# This Notebook will be a refreshable source of data that will guide purchasing decisions for those who want to know how much value they expect to get from a given sealed box (or pack!) of magic product. We'll start with Throne of Eldraine for recency.

# %% [markdown]
# ## Scraping From Cardsphere.com.
# Cardsphere is an asynchronous P2P marketplace where you can trade directly with other players at whatever price you choose and don't have to worry about warehousing, fake currency or high fees. We're pulling prices from this site as a starting point. You can find more about how they work at [Cardsphere.com](https://www.cardsphere.com)

# %%
import pandas as pd
import numpy as np
import string
import random
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import random as rd
import time
import matplotlib.pyplot as plt

# %%
##Scrape prices from Cardsphere
#These functions copied from BS4 tutorial

#Functions
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
#Test get function
rawhtml = simple_get(r'https://www.cardsphere.com/cards/16416')
len(rawhtml)
# Out:
# 15467

# %%
html = BeautifulSoup(rawhtml, 'html.parser')

# %% [markdown]
# The only way to proceed really is to dive into that html and find the tags of the objects you are looking for. You can use .prettify() if you really want to see the source. I found it was easier, however, to just navigate to the webpage and use Chrome (or firefox or opera) to left click the object and 'inspect element'. Then you can do more targeted looks as I do below.
#
# For ease of seeing what is happening, I am printing the HTML lines that I am grabbing from at the same time as I am saving the data I want into a dataframe.

# %%
dfp = pd.DataFrame(columns=['Price'])
for d in html.select('div'):
    try:
        if d['class'] == ['cs-col-xs-4','cs-col-sm-4']:
            print(d.text)
            dfp = dfp.append({'Price':d.text.strip()}, ignore_index=True)
    except:
        print('Error')
        print(d)
# Out:
# Error
# <div id="add-want-dialog-vue"></div>
# Error
# <div id="add-have-dialog-vue"></div>
#
#                         $0.16
#
#
#                         $0.32
#
#
#                         $0.32
#
#
#                         $0.33
#
#
#                         $0.34
#
#
#                         $0.88
#
#
#                         $1.21
#
#
#                         $4.88

# %%
dfp
# Out:
#    Price
# 0  $0.16
# 1  $0.32
# 2  $0.32
# 3  $0.33
# 4  $0.34
# 5  $0.88
# 6  $1.21
# 7  $4.88

# %%
dfe = pd.DataFrame(columns=['Edition'])
for a in html.select('a'):
    if r"cards/" in a['href']:
         print(a['href'])
         print(a.text)
         dfe = dfe.append({'Edition':a.text.strip()}, ignore_index=True)
# Out:
# /cards/16416
#
#
#                             Eternal Masters
#
# /cards/3514
#
#
#                             9th Edition
#
# /cards/2823
#
#
#                             8th Edition
#
# /cards/16415
#
#
#                             Eternal Masters (Foil)
#
# /cards/45970
#
#
#                             Urza's Destiny
#
# /cards/2822
#
#
#                             8th Edition (Foil)
#
# /cards/3513
#
#
#                             9th Edition (Foil)
#
# /cards/45969
#
#
#                             Urza's Destiny (Foil)

# %%
dfe
# Out:
#                   Edition
# 0         Eternal Masters
# 1             9th Edition
# 2             8th Edition
# 3  Eternal Masters (Foil)
# 4          Urza's Destiny
# 5      8th Edition (Foil)
# 6      9th Edition (Foil)
# 7   Urza's Destiny (Foil)

# %%
dfr = pd.DataFrame(columns=['Rarity'])
for a in html.select('i'):
    print(a)
    try:
        if not a.has_attr('aria-hidden'):
            print(a['class'][3][3:])
            dfr = dfr.append({'Rarity':a['class'][3][3:]}, ignore_index=True)
    except:
        print(_)
# Out:
# <i class="ss ss-fw ss-ema ss-common"></i>
# common
# <i class="ss ss-fw ss-ema ss-common"></i>
# common
# <i class="ss ss-fw ss-9ed ss-rare"></i>
# rare
# <i class="ss ss-fw ss-8ed ss-rare"></i>
# rare
# <i class="ss ss-fw ss-ema ss-common"></i>
# common
# <i class="ss ss-fw ss-uds ss-rare"></i>
# rare
# <i class="ss ss-fw ss-8ed ss-rare"></i>
# rare
# <i class="ss ss-fw ss-9ed ss-rare"></i>
# rare
# <i class="ss ss-fw ss-uds ss-rare"></i>
# rare
# <i aria-hidden="true" class="fa fa-arrow-up fa-fw"></i>
# <i aria-hidden="true" class="fa fa-fw fa-envelope"></i>
# <i aria-hidden="true" class="fa fa-fw fa-reddit-alien"></i>
# <i aria-hidden="true" class="fa fa-fw fa-facebook-official"></i>
# <i aria-hidden="true" class="fa fa-fw fa-twitter-square"></i>
# <i aria-hidden="true" class="fa fa-fw fa-comments"></i>
# <i aria-hidden="true" class="fa fa-fw fa-rss-square"></i>
# <i aria-hidden="true" class="fa fa-arrow-up fa-fw"></i>

# %%
dfr
# Out:
#    Rarity
# 0  common
# 1  common
# 2    rare
# 3    rare
# 4  common
# 5    rare
# 6    rare
# 7    rare
# 8    rare

# %%
dfr = dfr.drop([0],axis=0) #the selected card is always duplicated at the top of the list

# %% [markdown]
# Now we stitch all the data together to make a single frame of the prices and editions:

# %%
priceTab = pd.DataFrame(list(zip(dfe['Edition'],dfr['Rarity'],dfp['Price'])), columns=['Edition','Rarity','Price'])

# %%
priceTab
# Out:
#                   Edition  Rarity  Price
# 0         Eternal Masters  common  $0.16
# 1             9th Edition    rare  $0.32
# 2             8th Edition    rare  $0.32
# 3  Eternal Masters (Foil)  common  $0.33
# 4          Urza's Destiny    rare  $0.34
# 5      8th Edition (Foil)    rare  $0.88
# 6      9th Edition (Foil)    rare  $1.21
# 7   Urza's Destiny (Foil)    rare  $4.88

# %% [markdown]
# We did it! The Cardname is easy to add, since it doesn't change across the rows:

# %%
cardname = ''
for h in html.select('h3'):
    try:
        if h['class'] == ['text-center']:
            print(h.text)
            cardname = h.text.split('—')[0].strip()
    except:
        print("Error")
        print(h)
priceTab['Card Name'] = cardname
priceTab
# Out:
#                 Emperor Crocodile  —
#
# Eternal Masters
#
# Error
# <h3>Buy, Sell, and Trade Magic: The Gathering<sup>TM</sup> Cards</h3>
#                   Edition  Rarity  Price          Card Name
# 0         Eternal Masters  common  $0.16  Emperor Crocodile
# 1             9th Edition    rare  $0.32  Emperor Crocodile
# 2             8th Edition    rare  $0.32  Emperor Crocodile
# 3  Eternal Masters (Foil)  common  $0.33  Emperor Crocodile
# 4          Urza's Destiny    rare  $0.34  Emperor Crocodile
# 5      8th Edition (Foil)    rare  $0.88  Emperor Crocodile
# 6      9th Edition (Foil)    rare  $1.21  Emperor Crocodile
# 7   Urza's Destiny (Foil)    rare  $4.88  Emperor Crocodile

# %% [markdown]
# Lets functionize it! Note the 'sleep timer' of two seconds at the end. That is so Cardsphere doesn't realize we are a bot and stop responding to our requests. If I were doing this more often, I would set that to like 10 seconds to be courteous.

# %%
#Functionize
def get_prices(link):
    rawhtml = simple_get(link)
    errors = 0
    html = BeautifulSoup(rawhtml, 'html.parser')
    
    #Get Name
    cardname = ''
    for h in html.select('h3'):
        try:
            if h['class'] == ['text-center']:
                cardname = h.text.split('—')[0].strip()
        except:
            errors = errors+1
    
    #Get Edition
    dfe = pd.DataFrame(columns=['Edition'])
    for a in html.select('a'):
        try:
            if r"cards/" in a['href']:
                 dfe = dfe.append({'Edition':a.text.strip()}, ignore_index=True)
        except:
            errors = errors+1                
    
    #Get Prices 
    dfp = pd.DataFrame(columns=['Price'])
    for d in html.select('div'):
        #print(d['class'])
        #print(d)
        #print(d)
        try:
            if d['class'] == ['cs-col-xs-4','cs-col-sm-4']:
                dfp = dfp.append({'Price':d.text.strip()}, ignore_index=True)
        except:
            errors = errors+1
    
    #Get Rarity
    dfr = pd.DataFrame(columns=['Rarity'])
    for a in html.select('i'):
        try:
            if not a.has_attr('aria-hidden'):
                dfr = dfr.append({'Rarity':a['class'][3][3:].capitalize()}, ignore_index=True)
        except:
            errors = errors+1
    dfr = dfr.drop([0],axis=0) #the selected card is always duplicated at the top of the list
    
    #make final table
    priceTab = pd.DataFrame(list(zip(dfe['Edition'],dfr['Rarity'],dfp['Price'])), columns=['Edition','Rarity','Price'])
    priceTab['Card Name'] = cardname
    time.sleep(2) #be nice to the sites you are scraping
    return priceTab

# %% [markdown]
# If you're going to pull magic card prices, you might as well start with the King:

# %%
get_prices(r'https://www.cardsphere.com/cards/45620')
# Out:
#                  Edition Rarity       Price    Card Name
# 0    Collectors' Edition   Rare   $2,549.99  Black Lotus
# 1  International Edition   Rare   $2,549.99  Black Lotus
# 2              Unlimited   Rare  $16,019.24  Black Lotus
# 3  Limited Edition Alpha   Rare  $26,040.00  Black Lotus
# 4   Limited Edition Beta   Rare  $39,060.00  Black Lotus

# %% [markdown]
# Now lets try one with a looooot of printings:

# %%
get_prices(r'https://www.cardsphere.com/cards/36276')
# Out:
#                            Edition  Rarity   Price     Card Name
# 0                Return to Ravnica  Common   $0.14  Giant Growth
# 1                       Magic 2011  Common   $0.14  Giant Growth
# 2                      4th Edition  Common   $0.14  Giant Growth
# 3                       Magic 2014  Common   $0.14  Giant Growth
# 4                          Ice Age  Common   $0.14  Giant Growth
# 5                       Magic 2010  Common   $0.14  Giant Growth
# 6                       Masters 25  Common   $0.14  Giant Growth
# 7                 War of the Spark  Common   $0.14  Giant Growth
# 8                      9th Edition  Common   $0.14  Giant Growth
# 9                      7th Edition  Common   $0.15  Giant Growth
# 10                     8th Edition  Common   $0.16  Giant Growth
# 11                     6th Edition  Common   $0.16  Giant Growth
# 12                      Battlebond  Common   $0.16  Giant Growth
# 13                    10th Edition  Common   $0.18  Giant Growth
# 14                     5th Edition  Common   $0.18  Giant Growth
# 15                 Mystery Booster  Common   $0.19  Giant Growth
# 16                         Revised  Common   $0.19  Giant Growth
# 17  Duel Decks: Garruk vs. Liliana  Common   $0.20  Giant Growth
# 18   Duel Decks: Elves vs. Goblins  Common   $0.20  Giant Growth
# 19                     Anthologies  Common   $0.21  Giant Growth
# 20      Duels of the Planeswalkers  Common   $0.21  Giant Growth
# 21                     Deckmasters  Common   $0.21  Giant Growth
# 22             Explorers of Ixalan  Common   $0.23  Giant Growth
# 23                        Beatdown  Common   $0.23  Giant Growth
# 24               Masters 25 (Foil)  Common   $0.25  Giant Growth
# 25         War of the Spark (Foil)  Common   $0.28  Giant Growth
# 26               Battlebond (Foil)  Common   $0.30  Giant Growth
# 27        Return to Ravnica (Foil)  Common   $0.30  Giant Growth
# 28               Magic 2014 (Foil)  Common   $0.33  Giant Growth
# 29               Magic 2011 (Foil)  Common   $0.37  Giant Growth
# 30                   Battle Royale  Common   $0.44  Giant Growth
# 31               Magic 2010 (Foil)  Common   $0.44  Giant Growth
# 32              8th Edition (Foil)  Common   $0.74  Giant Growth
# 33             10th Edition (Foil)  Common   $0.75  Giant Growth
# 34              9th Edition (Foil)  Common   $0.83  Giant Growth
# 35                       Unlimited  Common   $1.84  Giant Growth
# 36                  Player Rewards       C   $2.00  Giant Growth
# 37           JSS/MSS Promos (Foil)       C   $2.12  Giant Growth
# 38               FNM Promos (Foil)       C   $4.24  Giant Growth
# 39             Collectors' Edition  Common   $5.94  Giant Growth
# 40           International Edition  Common   $8.49  Giant Growth
# 41            Limited Edition Beta  Common  $20.87  Giant Growth
# 42              7th Edition (Foil)  Common  $37.20  Giant Growth
# 43           Limited Edition Alpha  Common  $44.56  Giant Growth

# %% [markdown]
# For fun, you can do it with a random card!

# %%
num = rd.randint(0,61636)
print(num)
get_prices('https://www.cardsphere.com/cards/{}'.format(num))
# Out:
# 40733
#           Edition  Rarity  Price     Card Name
# 0         Scourge  Common  $0.16  Astral Steel
# 1  Scourge (Foil)  Common  $0.30  Astral Steel

# %% [markdown]
# ## Expected Values and Variances of Sealed Magic Product

# %% [markdown]
# Now, lets put a whole set's worth into a frame so we can do our expected values. Cardsphere gives each card a unique ordinal number, so we can get the whole set by inputting a range. I just determined this range by checking the first and last card in the set with my eyes, but will update this later to use a 'guess and check' model based on scraping.

# %%
df_eld = pd.DataFrame()
for x in range(61850,62119):
    #These are all the ELD cards
    try:
        df_eld = df_eld.append(get_prices('https://www.cardsphere.com/cards/{}'.format(x)), ignore_index=True)
    except:
        print(x)

# %%
#Check to make sure we got all of the cards
df_norm = df_eld[df_eld['Edition'] == 'Throne of Eldraine']
df_norm.shape
# Out:
# (269, 4)

# %%
df_norm['Price'] = [float(s[1:]) for s in df_norm['Price']] #Strip the $ sign
# Out:
# C:\Users\attic\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Ignoring collation, which is one of Wizards greatest kept secrets, we can 'make' boxes as sets of 36 packs and find their Expected Value.
# Thankfully, Expected Value is additive, and thus the expected value of a booster is the sum of the expected value of the 10  commons, 3 uncommons, and 1 rare/mythic.

# %%
#Expected Value of Commons
evc = df_norm[df_norm['Rarity'] == 'Common']['Price'].mean()
evu = df_norm[df_norm['Rarity'] == 'Uncommon']['Price'].mean()
evrm = (df_norm[df_norm['Rarity'] == 'Mythic']['Price'].mean() + 7*df_norm[df_norm['Rarity'] == 'Rare']['Price'].mean())/8

# %%
print('evc = %1.2f evu = %1.2f evrm = %1.2f' % (evc,evu,evrm))
# Out:
# evc = 0.14 evu = 0.24 evrm = 2.35

# %%
#Pack EV
evpack = 11*evc+3*evu+1*evrm
print("$%.2f" % evpack)
# Out:
# $4.66

# %%
#box EV
evbox = 36*evpack
print("$%.2f" % evbox)
# Out:
# $167.91

# %% [markdown]
# Variance is also additive! The variance of (A+B) where A and B are independent random variables is Var(A) + Var(B). The independence assumption is crucial. It lets us ignore covariances. In reality, collation probably causes some covariance.

# %%
#Expected Value of Commons and uncommons
varc = df_norm[df_norm['Rarity'] == 'Common']['Price'].var()
varu = df_norm[df_norm['Rarity'] == 'Uncommon']['Price'].var()

# %% [markdown]
# Variance of the rare mythic slot is a little more complicated. the slot is a combintation of RVs - 1/8*M + 7/8*R.
# $$Var(1/8M + 7/8R) = 1/8^2 * Var(M) + 7/8^2 * Var(R)$$

# %%
varrm = ((1/8)**2)*df_norm[df_norm['Rarity'] == 'Mythic']['Price'].var() + \
((7/8)**2)*df_norm[df_norm['Rarity'] == 'Rare']['Price'].var()

# %%
print('varc = %1.2f varu = %1.2f varrm = %1.2f' % (varc,varu,varrm))
# Out:
# varc = 0.00 varu = 0.06 varrm = 5.71

# %%
#Variance of a pack
varpack = 11*varc + 3*varu + varrm
print("$%.2f" % varpack)
# Out:
# $5.90

# %%
#Variance of a box
varbox = 36*varpack
print("$%.2f" % varbox)
# Out:
# $212.51

# %% [markdown]
# These are means and variances, but we can actually simulate a pack or box and measure its value over a bunch of iterations. This is like a very basic monte carlo.

# %%
commons = df_norm[df_norm['Rarity'] == 'Common'].sample(n=11)
uncommons = df_norm[df_norm['Rarity'] == 'Uncommon'].sample(n=3)

m = np.random.randint(1,9)

if np.random.randint(1,9) == 8:
    rareslot = df_norm[df_norm['Rarity'] == 'Mythic'].sample(n=1)
else: 
    rareslot = df_norm[df_norm['Rarity'] == 'Rare'].sample(n=1)

pack = pd.concat([commons,uncommons,rareslot])

# %%
pack
# Out:
#                  Edition    Rarity  Price                          Card Name
# 1051  Throne of Eldraine    Common   0.13                        Tome Raider
# 1062  Throne of Eldraine    Common   0.14                   Vantress Paladin
# 50    Throne of Eldraine    Common   0.14               Blow Your House Down
# 845   Throne of Eldraine    Common   0.14                  Rosethorn Halberd
# 387   Throne of Eldraine    Common   0.14                       Henge Walker
# 631   Throne of Eldraine    Common   0.14                        Ogre Errant
# 1068  Throne of Eldraine    Common   0.14                        Weapon Rack
# 134   Throne of Eldraine    Common   0.14                    Crystal Slipper
# 321   Throne of Eldraine    Common   0.13              Fortifying Provisions
# 1045  Throne of Eldraine    Common   0.19              Thrill of Possibility
# 538   Throne of Eldraine    Common   0.14                    Mantle of Tides
# 1064  Throne of Eldraine  Uncommon   0.19                   Venerable Knight
# 9     Throne of Eldraine  Uncommon   0.19  Animating Faerie // Bring to Life
# 772   Throne of Eldraine  Uncommon   0.18               Rally for the Throne
# 373   Throne of Eldraine      Rare   0.28                 Happily Ever After

# %%
#make it a function:
def makePack(set_df):
    commons = set_df[set_df['Rarity'] == 'Common'].sample(n=11)
    uncommons = set_df[set_df['Rarity'] == 'Uncommon'].sample(n=3)

    if np.random.randint(1,9) == 8:
        rareslot = set_df[set_df['Rarity'] == 'Mythic'].sample(n=1)
    else: 
        rareslot = set_df[set_df['Rarity'] == 'Rare'].sample(n=1)

    return pd.concat([commons,uncommons,rareslot])

# %%
makePack(df_norm)
# Out:
#                  Edition    Rarity  Price  \
# 268   Throne of Eldraine    Common   0.13
# 618   Throne of Eldraine    Common   0.37
# 361   Throne of Eldraine    Common   0.14
# 521   Throne of Eldraine    Common   0.14
# 916   Throne of Eldraine    Common   0.14
# 654   Throne of Eldraine    Common   0.18
# 30    Throne of Eldraine    Common   0.13
# 134   Throne of Eldraine    Common   0.14
# 843   Throne of Eldraine    Common   0.13
# 1102  Throne of Eldraine    Common   0.16
# 1068  Throne of Eldraine    Common   0.14
# 323   Throne of Eldraine  Uncommon   0.23
# 37    Throne of Eldraine  Uncommon   0.18
# 800   Throne of Eldraine  Uncommon   0.19
# 151   Throne of Eldraine      Rare   0.46
#
#                                  Card Name
# 268                             Flutterfox
# 618                       Mystic Sanctuary
# 361                      Gingerbread Cabin
# 521                      Locthwain Paladin
# 916                      Steelgaze Griffin
# 654                                    Opt
# 30                          Barrow Witches
# 134                        Crystal Slipper
# 843   Rosethorn Acolyte // Seasonal Ritual
# 1102                         Witching Well
# 1068                           Weapon Rack
# 323     Foulmire Knight // Profane Insight
# 37                      Belle of the Brawl
# 800                         Resolute Rider
# 151                          Doom Foretold

# %%
 print("$%.2f" % makePack(df_norm)['Price'].sum())
# Out:
# $5.21

# %% [markdown]
# Now lets graph that price over a thousand packs, and then a thousand boxes.

# %%
df_mcpacks = pd.DataFrame(columns=['Pack Value'])
for i in range(0,10000):
    df_mcpacks = df_mcpacks.append({'Pack Value':makePack(df_norm)['Price'].sum()},ignore_index=True)
plt.hist(df_mcpacks['Pack Value'],bins=50);

# %% [markdown]
# Now with Boxes!

# %%
def makeBox(set_df):
    box = pd.DataFrame()
    for i in range(0,36):
        box = box.append(makePack(set_df),ignore_index=True)
    return box

# %%
#it works!
makeBox(df_norm).head(30)
# Out:
#                Edition    Rarity  Price  \
# 0   Throne of Eldraine    Common   0.16
# 1   Throne of Eldraine    Common   0.14
# 2   Throne of Eldraine    Common   0.14
# 3   Throne of Eldraine    Common   0.14
# 4   Throne of Eldraine    Common   0.14
# 5   Throne of Eldraine    Common   0.14
# 6   Throne of Eldraine    Common   0.14
# 7   Throne of Eldraine    Common   0.14
# 8   Throne of Eldraine    Common   0.14
# 9   Throne of Eldraine    Common   0.14
# 10  Throne of Eldraine    Common   0.13
# 11  Throne of Eldraine  Uncommon   0.23
# 12  Throne of Eldraine  Uncommon   0.18
# 13  Throne of Eldraine  Uncommon   2.20
# 14  Throne of Eldraine    Mythic  15.08
# 15  Throne of Eldraine    Common   0.14
# 16  Throne of Eldraine    Common   0.14
# 17  Throne of Eldraine    Common   0.14
# 18  Throne of Eldraine    Common   0.14
# 19  Throne of Eldraine    Common   0.14
# 20  Throne of Eldraine    Common   0.13
# 21  Throne of Eldraine    Common   0.14
# 22  Throne of Eldraine    Common   0.14
# 23  Throne of Eldraine    Common   0.14
# 24  Throne of Eldraine    Common   0.17
# 25  Throne of Eldraine    Common   0.14
# 26  Throne of Eldraine  Uncommon   0.19
# 27  Throne of Eldraine  Uncommon   0.23
# 28  Throne of Eldraine  Uncommon   0.19
# 29  Throne of Eldraine      Rare   1.27
#
#                                  Card Name
# 0   Merfolk Secretkeeper // Venture Deeper
# 1                            Wolf's Quarry
# 2                       Locthwain Gargoyle
# 3                      Brimstone Trebuchet
# 4                          Bake into a Pie
# 5                         Wildwood Tracker
# 6                        Rosethorn Halberd
# 7                           Giant's Skewer
# 8                              Roving Keep
# 9                     Scorching Dragonfire
# 10                         Sporecap Spider
# 11                          Into the Story
# 12                        Deathless Knight
# 13                        Mystical Dispute
# 14                         The Great Henge
# 15                        True Love's Kiss
# 16                    Trapped in the Tower
# 17                       Rosethorn Halberd
# 18                     Brimstone Trebuchet
# 19      Garenbrig Carver // Shield's Might
# 20                        Malevolent Noble
# 21         Tuinvale Treefolk // Oaken Boon
# 22                             Ogre Errant
# 23                       Ardenvale Paladin
# 24                           Witching Well
# 25                       Steelgaze Griffin
# 26                 Grumgully, the Generous
# 27                      Tournament Grounds
# 28             Syr Elenora, the Discerning
# 29                        Castle Ardenvale

# %%
print("$%.2f" % makeBox(df_norm)['Price'].sum())
# Out:
# $166.15

# %%
#Onward with the graphing
df_mcboxes = pd.DataFrame(columns=['Box Value'])
for i in range(0,1000):
    df_mcboxes = df_mcboxes.append({'Box Value':makeBox(df_norm)['Price'].sum()},ignore_index=True)
plt.hist(df_mcboxes['Box Value'],bins=50);

# %% [markdown]
# Quite predictably, these histograms are centered on the Expected Values (Means) of each distribution. What I was not expecting is that the packs exhibited a heavily right-skewed distribution whereas the boxes are much closer to normally distributed.
